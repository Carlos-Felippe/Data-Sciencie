# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos-Felippe/Data-Sciencie/blob/main/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Visualização de dados em Python

import matplotlib.pyplot as plt

x = [1, 2, 4, 5]
y = [2, 3 ,8, 9]

plt.plot(x, y)
plt.show()
